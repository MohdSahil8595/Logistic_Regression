# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdSahil8595/Logistic_Regression/blob/main/PRODIGY_ml_02KMeans_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Mall_Customers.csv")

# %%
df.head(6)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.describe()
# Out:
#        CustomerID      Gender         Age  Annual Income (k$)  \
# count  200.000000  200.000000  200.000000          200.000000
# mean   100.500000    0.440000   38.850000           60.560000
# std     57.879185    0.497633   13.969007           26.264721
# min      1.000000    0.000000   18.000000           15.000000
# 25%     50.750000    0.000000   28.750000           41.500000
# 50%    100.500000    0.000000   36.000000           61.500000
# 75%    150.250000    1.000000   49.000000           78.000000
# max    200.000000    1.000000   70.000000          137.000000
#
#        Spending Score (1-100)
# count              200.000000
# mean                50.200000
# std                 25.823522
# min                  1.000000
# 25%                 34.750000
# 50%                 50.000000
# 75%                 73.000000
# max                 99.000000

# %%
df_1 = df.drop(columns=['CustomerID'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_1["Gender"] = le.fit_transform(df["Gender"])
# male --> 1
# female --> 0

# %%
df_1
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_1)

# %% [markdown]
# **ELbow Method**

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters = i, random_state=50)
  kmeans.fit(X_scaled)
  wcss.append(kmeans.inertia_)

# %% [markdown]
# **Plotting Elbow curve**

# %%
plt.figure()
plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

# %% [markdown]
# **Apply K-Means algorithm**

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
df_1['cluster'] = clusters
df_1.head(6)
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  cluster
# 0       1   19                  15                      39        2
# 1       1   21                  15                      81        2
# 2       0   20                  16                       6        3
# 3       0   23                  16                      77        3
# 4       0   31                  17                      40        3
# 5       0   22                  17                      76        3

# %%
plt.figure()
sns.scatterplot(
    x=df_1["Annual Income (k$)"],
    y=df_1["Spending Score (1-100)"],
    hue=df_1["cluster"],
    palette="viridis"
)
plt.title("Customer Segmentation using K-Means")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

kmeans = KMeans(n_clusters=4, random_state=42)
labels = kmeans.fit_predict(X_pca)

# %%
plt.scatter(X_pca[:,0], X_pca[:,1], c=labels)
plt.title("Clusters after PCA")
plt.show()
